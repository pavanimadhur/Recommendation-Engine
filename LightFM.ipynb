# %% [markdown]
# # LightFM is a Python implementation of a hybrid recommendation algorithms for both implicit and explicit feedbacks
#
# It is a hybrid content-collaborative model which represents users and items as linear combinations of their content features’ latent factors. The model learns embeddings or latent representations of the users and items in such a way that it encodes user preferences over items. These representations produce scores for every item for a given user; items scored highly are more likely to be interesting to the user.
#
# The user and item embeddings are estimated for every feature, and these features are then added together to be the final representations for users and items.
#
# For example, for user i, the model retrieves the i-th row of the feature matrix to find the features with non-zero weights. The embeddings for these features will then be added together to become the user representation e.g. if user 10 has weight 1 in the 5th column of the user feature matrix, and weight 3 in the 20th column, the user 10’s representation is the sum of embedding for the 5th and the 20th features multiplying their corresponding weights. The representation for each items is computed in the same approach.

# %%
pip install lightfm
# Out:
# Requirement already satisfied: lightfm in d:\anaconda\lib\site-packages (1.16)
# Requirement already satisfied: scikit-learn in d:\anaconda\lib\site-packages (from lightfm) (0.23.2)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from lightfm) (2.24.0)
# Requirement already satisfied: scipy>=0.17.0 in d:\anaconda\lib\site-packages (from lightfm) (1.5.2)
# Requirement already satisfied: numpy in c:\users\pavani\appdata\roaming\python\python38\site-packages (from lightfm) (1.22.1)
# Requirement already satisfied: joblib>=0.11 in d:\anaconda\lib\site-packages (from scikit-learn->lightfm) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\anaconda\lib\site-packages (from scikit-learn->lightfm) (2.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\anaconda\lib\site-packages (from requests->lightfm) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->lightfm) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in d:\anaconda\lib\site-packages (from requests->lightfm) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->lightfm) (2020.6.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os

import itertools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import lightfm
from lightfm import LightFM
from lightfm.data import Dataset
from lightfm import cross_validation

# Import LightFM's evaluation metrics
from lightfm.evaluation import precision_at_k as lightfm_prec_at_k
from lightfm.evaluation import recall_at_k as lightfm_recall_at_k

# Import repo's evaluation metrics
from recommenders.evaluation.python_evaluation import (
    precision_at_k, recall_at_k)

from recommenders.utils.timer import Timer
from recommenders.datasets import movielens
from recommenders.models.lightfm.lightfm_utils import (
    track_model_metrics, prepare_test_df, prepare_all_predictions,
    compare_metric, similar_users, similar_items)

print("System version: {}".format(sys.version))
print("LightFM version: {}".format(lightfm.__version__))
# Out:
# D:\Anaconda\lib\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(
# System version: 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]
# LightFM version: 1.16

# %%
# default number of recommendations
K = 10
# percentage of data used for testing
TEST_PERCENTAGE = 0.25
# model learning rate
LEARNING_RATE = 0.25
# no of latent factors
NO_COMPONENTS = 20
# no of epochs to fit model
NO_EPOCHS = 20
# no of threads to fit model
NO_THREADS = 32
# regularisation for both user and item features
ITEM_ALPHA=1e-6
USER_ALPHA=1e-6
# seed for pseudonumber generations
SEEDNO = 42

# %%
filter_reviews = pd.read_csv('C:\\Users\\PAVANI\\Documents\\Reading course\\Reading course\\Recommendation systems\\8Lkh_with_Sentiment_analysis.csv')

# %%
filter_reviews = filter_reviews.drop('Unnamed: 0', axis=1)
ratings = filter_reviews[['user_name', 'item_id', 'review_polarity']]

# %%
genre_data = pd.read_csv('3k_game_Data.csv')

# %%
genre_data = genre_data[['item_id', 'genre']]

# %%
final_dataframe = pd.merge(ratings, genre_data, on='item_id')

# %%
final_dataframe = final_dataframe.rename(columns={'userId': 'userID', 'itemId': 'itemID', 'rating': 'rating'})

# %%
final_dataframe.head()
# Out:
#      user_name  item_id  review_polarity   genre
# 0  coolguyrift    32430                3  Action
# 1         bort    32430                3  Action
# 2    ヽ(｡･ω･｡)ﾉ    32430                3  Action
# 3       lowkey    32430                2  Action
# 4         greg    32430                2  Action

# %%
dataset = Dataset()

# %%
dataset.fit(users=final_dataframe['userID'], 
            items=final_dataframe['itemID'])
num_users, num_items = dataset.interactions_shape()
print(f'Num users: {num_users}, num_items: {num_items}.')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'userID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-e71c3f823b61> in <module>
# ----> 1 dataset.fit(users=final_dataframe['userID'],
#       2             items=final_dataframe['itemID'])
#       3 num_users, num_items = dataset.interactions_shape()
#       4 print(f'Num users: {num_users}, num_items: {num_items}.')
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'userID'

# %% [markdown]
# # Building Interaction Matrix

# %%
(interactions, weights) = dataset.build_interactions(final_dataframe.iloc[:, 0:3].values)

# %%
train_interactions, test_interactions = cross_validation.random_train_test_split(
    interactions, test_percentage=TEST_PERCENTAGE,random_state=np.random.RandomState(SEEDNO))

# %%
print(f"Shape of train interactions: {train_interactions.shape}")
print(f"Shape of test interactions: {test_interactions.shape}")

# %%
model1 = LightFM(loss='warp', no_components=NO_COMPONENTS, 
                 learning_rate=LEARNING_RATE,                 
                 random_state=np.random.RandomState(SEEDNO))
model1.fit(interactions=train_interactions,
          epochs=NO_EPOCHS);

# %%
uids, iids, interaction_data = cross_validation._shuffle(
    interactions.row, interactions.col, interactions.data, 
    random_state=np.random.RandomState(SEEDNO))

cutoff = int((1.0 - TEST_PERCENTAGE) * len(uids))
test_idx = slice(cutoff, None)

# %%
dic_users={}
i=1
for index, row in final_dataframe.iterrows():
    if row['userID'] not in dic_users:
        dic_users[row['userID']] = i
        i+=1
    
len(dic_users)
# Out:
# 9145

# %%
def get_recommendations(username):

    # get the list of the movie ids
    unique_ids = final_dataframe['itemID'].unique()
    ids = final_dataframe.loc[final_dataframe['userID']== username, 'itemID']

    # remove the rated movies for the recommendations
    movies_to_predict = np.setdiff1d(unique_ids,ids)
    return movies_to_predict

movies_to_predict = get_recommendations('lumpy')
print(len(movies_to_predict))
my_recs = []
for iid in movies_to_predict:
    my_recs.append((iid, model1.predict(dic_users['lumpy'],iid)))
 
df_result = pd.DataFrame(my_recs, columns=['item_id', 'predictions']).sort_values('predictions', ascending=False).head(20)
df_result
# Out:
# 2954
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-b110c9458080> in <module>
#      13 my_recs = []
#      14 for iid in movies_to_predict:
# ---> 15     my_recs.append((iid, model1.predict(dic_users['lumpy'],iid)))
#      16
#      17 df_result = pd.DataFrame(my_recs, columns=['item_id', 'predictions']).sort_values('predictions', ascending=False).head(20)
#
# D:\Anaconda\lib\site-packages\lightfm\lightfm.py in predict(self, user_ids, item_ids, item_features, user_features, num_threads)
#     783
#     784         if isinstance(user_ids, int):
# --> 785             user_ids = np.repeat(np.int32(user_ids), len(item_ids))
#     786
#     787         if not isinstance(user_ids, np.ndarray):
#
# TypeError: object of type 'numpy.int64' has no len()

# %%
uid_map, ufeature_map, iid_map, ifeature_map = dataset.mapping()

# %%
ifeature_map
# Out:
# {32430: 0,
#  10180: 1,
#  230050: 2,
#  33230: 3,
#  231200: 4,
#  266510: 5,
#  220240: 6,
#  39120: 7,
#  239160: 8,
#  4000: 9,
#  107410: 10,
#  25800: 11,
#  388410: 12,
#  227860: 13,
#  433340: 14,
#  9900: 15,
#  243950: 16,
#  50300: 17,
#  421020: 18,
#  221910: 19,
#  431240: 20,
#  221100: 21,
#  330830: 22,
#  319630: 23,
#  349700: 24,
#  227300: 25,
#  204450: 26,
#  302830: 27,
#  360640: 28,
#  264280: 29,
#  203290: 30,
#  11450: 31,
#  239200: 32,
#  212680: 33,
#  394230: 34,
#  452060: 35,
#  240: 36,
#  456670: 37,
#  391460: 38,
#  215530: 39,
#  674940: 40,
#  352520: 41,
#  17500: 42,
#  588430: 43,
#  230230: 44,
#  368370: 45,
#  202970: 46,
#  485380: 47,
#  205190: 48,
#  630: 49,
#  254200: 50,
#  233270: 51,
#  236110: 52,
#  322110: 53,
#  433850: 54,
#  110800: 55,
#  259080: 56,
#  3590: 57,
#  363600: 58,
#  208650: 59,
#  271590: 60,
#  8190: 61,
#  301910: 62,
#  252490: 63,
#  48700: 64,
#  4500: 65,
#  221680: 66,
#  241930: 67,
#  391540: 68,
#  312990: 69,
#  303210: 70,
#  298610: 71,
#  384300: 72,
#  367600: 73,
#  16450: 74,
#  12120: 75,
#  248630: 76,
#  16720: 77,
#  347430: 78,
#  55140: 79,
#  200510: 80,
#  9010: 81,
#  299030: 82,
#  444090: 83,
#  410670: 84,
#  250900: 85,
#  601510: 86,
#  269290: 87,
#  335300: 88,
#  241600: 89,
#  392110: 90,
#  49600: 91,
#  311310: 92,
#  243470: 93,
#  331470: 94,
#  269210: 95,
#  258970: 96,
#  227000: 97,
#  223100: 98,
#  225540: 99,
#  220160: 100,
#  440: 101,
#  50: 102,
#  367520: 103,
#  504370: 104,
#  730: 105,
#  24200: 106,
#  210970: 107,
#  381560: 108,
#  238010: 109,
#  431960: 110,
#  97000: 111,
#  403640: 112,
#  232090: 113,
#  221020: 114,
#  2600: 115,
#  233130: 116,
#  273350: 117,
#  301520: 118,
#  32370: 119,
#  414340: 120,
#  247080: 121,
#  33460: 122,
#  35140: 123,
#  322500: 124,
#  270210: 125,
#  652980: 126,
#  253290: 127,
#  407530: 128,
#  63380: 129,
#  291550: 130,
#  291410: 131,
#  378610: 132,
#  247660: 133,
#  383870: 134,
#  582660: 135,
#  454060: 136,
#  327890: 137,
#  332800: 138,
#  263500: 139,
#  282900: 140,
#  322330: 141,
#  321800: 142,
#  274500: 143,
#  8930: 144,
#  30: 145,
#  39140: 146,
#  20: 147,
#  444250: 148,
#  80: 149,
#  225080: 150,
#  245170: 151,
#  402330: 152,
#  259550: 153,
#  324800: 154,
#  108700: 155,
#  351970: 156,
#  12770: 157,
#  220440: 158,
#  438640: 159,
#  346110: 160,
#  232910: 161,
#  243450: 162,
#  281990: 163,
#  346560: 164,
#  310080: 165,
#  236090: 166,
#  215510: 167,
#  292910: 168,
#  330580: 169,
#  286690: 170,
#  289650: 171,
#  203680: 172,
#  377160: 173,
#  227180: 174,
#  212800: 175,
#  231430: 176,
#  290300: 177,
#  207690: 178,
#  22610: 179,
#  201810: 180,
#  290080: 181,
#  296770: 182,
#  257510: 183,
#  263820: 184,
#  219640: 185,
#  233450: 186,
#  516510: 187,
#  355840: 188,
#  8980: 189,
#  412880: 190,
#  203830: 191,
#  377840: 192,
#  620: 193,
#  268910: 194,
#  247000: 195,
#  203140: 196,
#  307780: 197,
#  296490: 198,
#  104900: 199,
#  230410: 200,
#  333930: 201,
#  49520: 202,
#  3720: 203,
#  301860: 204,
#  252150: 205,
#  433950: 206,
#  224260: 207,
#  356190: 208,
#  386940: 209,
#  212480: 210,
#  449220: 211,
#  438740: 212,
#  262410: 213,
#  255420: 214,
#  55230: 215,
#  306130: 216,
#  339610: 217,
#  225420: 218,
#  32470: 219,
#  205100: 220,
#  113200: 221,
#  247910: 222,
#  104700: 223,
#  67370: 224,
#  324310: 225,
#  237930: 226,
#  102500: 227,
#  25000: 228,
#  47890: 229,
#  2820: 230,
#  220: 231,
#  6880: 232,
#  209000: 233,
#  371970: 234,
#  418460: 235,
#  17410: 236,
#  40390: 237,
#  6060: 238,
#  323370: 239,
#  287980: 240,
#  413420: 241,
#  505170: 242,
#  409690: 243,
#  429470: 244,
#  261570: 245,
#  369580: 246,
#  111600: 247,
#  221640: 248,
#  57900: 249,
#  461560: 250,
#  345350: 251,
#  222140: 252,
#  417860: 253,
#  402710: 254,
#  355180: 255,
#  224600: 256,
#  368500: 257,
#  233720: 258,
#  208090: 259,
#  311560: 260,
#  228280: 261,
#  238320: 262,
#  204300: 263,
#  200210: 264,
#  361300: 265,
#  240440: 266,
#  229480: 267,
#  6370: 268,
#  211400: 269,
#  466560: 270,
#  435150: 271,
#  467360: 272,
#  108600: 273,
#  9420: 274,
#  400: 275,
#  294860: 276,
#  319510: 277,
#  643270: 278,
#  209160: 279,
#  42700: 280,
#  248860: 281,
#  236430: 282,
#  466240: 283,
#  233290: 284,
#  224460: 285,
#  242820: 286,
#  57690: 287,
#  302670: 288,
#  34030: 289,
#  290790: 290,
#  307670: 291,
#  205840: 292,
#  113400: 293,
#  2620: 294,
#  236150: 295,
#  107100: 296,
#  263060: 297,
#  227940: 298,
#  130: 299,
#  374320: 300,
#  445220: 301,
#  10150: 302,
#  205610: 303,
#  240760: 304,
#  239030: 305,
#  239700: 306,
#  273770: 307,
#  307880: 308,
#  262060: 309,
#  255070: 310,
#  359050: 311,
#  313120: 312,
#  365300: 313,
#  32360: 314,
#  271670: 315,
#  28000: 316,
#  33120: 317,
#  340: 318,
#  262830: 319,
#  277890: 320,
#  274310: 321,
#  242680: 322,
#  224580: 323,
#  274170: 324,
#  572410: 325,
#  304050: 326,
#  204080: 327,
#  550650: 328,
#  251690: 329,
#  427250: 330,
#  253710: 331,
#  449830: 332,
#  550900: 333,
#  389730: 334,
#  424280: 335,
#  39690: 336,
#  321260: 337,
#  2400: 338,
#  268050: 339,
#  459220: 340,
#  4700: 341,
#  98800: 342,
#  266170: 343,
#  500: 344,
#  339800: 345,
#  614570: 346,
#  218230: 347,
#  24980: 348,
#  447040: 349,
#  242920: 350,
#  202170: 351,
#  359550: 352,
#  266430: 353,
#  7520: 354,
#  314450: 355,
#  208730: 356,
#  24420: 357,
#  50620: 358,
#  219150: 359,
#  15100: 360,
#  22200: 361,
#  518790: 362,
#  212500: 363,
#  265610: 364,
#  319550: 365,
#  224820: 366,
#  206210: 367,
#  220200: 368,
#  289070: 369,
#  234190: 370,
#  234140: 371,
#  205230: 372,
#  2870: 373,
#  248610: 374,
#  235380: 375,
#  434570: 376,
#  376210: 377,
#  286940: 378,
#  99900: 379,
#  233740: 380,
#  324160: 381,
#  238930: 382,
#  205730: 383,
#  35720: 384,
#  251170: 385,
#  265930: 386,
#  221260: 387,
#  217200: 388,
#  251990: 389,
#  463530: 390,
#  331670: 391,
#  424840: 392,
#  216110: 393,
#  286040: 394,
#  12100: 395,
#  208500: 396,
#  326410: 397,
#  405640: 398,
#  393420: 399,
#  243120: 400,
#  300570: 401,
#  208480: 402,
#  22350: 403,
#  23490: 404,
#  305620: 405,
#  225640: 406,
#  206420: 407,
#  95300: 408,
#  17470: 409,
#  582160: 410,
#  278360: 411,
#  402020: 412,
#  10090: 413,
#  268130: 414,
#  242550: 415,
#  250180: 416,
#  261030: 417,
#  356670: 418,
#  363970: 419,
#  234160: 420,
#  330840: 421,
#  241540: 422,
#  324810: 423,
#  234490: 424,
#  258520: 425,
#  235540: 426,
#  298240: 427,
#  298050: 428,
#  92000: 429,
#  623940: 430,
#  212010: 431,
#  219890: 432,
#  239350: 433,
#  26800: 434,
#  407810: 435,
#  406970: 436,
#  211820: 437,
#  440900: 438,
#  207230: 439,
#  94400: 440,
#  265690: 441,
#  20920: 442,
#  41300: 443,
#  211420: 444,
#  17460: 445,
#  323470: 446,
#  422810: 447,
#  428430: 448,
#  201570: 449,
#  507490: 450,
#  704550: 451,
#  91600: 452,
#  238430: 453,
#  236870: 454,
#  334230: 455,
#  3710: 456,
#  436150: 457,
#  12110: 458,
#  584400: 459,
#  612880: 460,
#  420290: 461,
#  55150: 462,
#  299360: 463,
#  237110: 464,
#  242880: 465,
#  70300: 466,
#  238460: 467,
#  372800: 468,
#  362890: 469,
#  475550: 470,
#  31700: 471,
#  385560: 472,
#  568570: 473,
#  11280: 474,
#  304390: 475,
#  4920: 476,
#  328060: 477,
#  7510: 478,
#  40950: 479,
#  498240: 480,
#  357480: 481,
#  506610: 482,
#  249130: 483,
#  318220: 484,
#  319910: 485,
#  51100: 486,
#  40800: 487,
#  214770: 488,
#  332200: 489,
#  48000: 490,
#  449540: 491,
#  270550: 492,
#  601430: 493,
#  92800: 494,
#  453480: 495,
#  24740: 496,
#  63700: 497,
#  312520: 498,
#  204360: 499,
#  410380: 500,
#  208580: 501,
#  8400: 502,
#  340270: 503,
#  351940: 504,
#  6910: 505,
#  274290: 506,
#  624090: 507,
#  239140: 508,
#  17080: 509,
#  228300: 510,
#  289130: 511,
#  405820: 512,
#  485310: 513,
#  311210: 514,
#  296970: 515,
#  55040: 516,
#  33930: 517,
#  108800: 518,
#  367670: 519,
#  65980: 520,
#  233840: 521,
#  227220: 522,
#  365360: 523,
#  289090: 524,
#  387990: 525,
#  268420: 526,
#  214700: 527,
#  559210: 528,
#  419480: 529,
#  373770: 530,
#  107310: 531,
#  41000: 532,
#  19900: 533,
#  357900: 534,
#  353360: 535,
#  418070: 536,
#  215790: 537,
#  246680: 538,
#  292120: 539,
#  331200: 540,
#  365590: 541,
#  288930: 542,
#  365670: 543,
#  247730: 544,
#  17390: 545,
#  313340: 546,
#  216150: 547,
#  274190: 548,
#  351910: 549,
#  463150: 550,
#  312530: 551,
#  115100: 552,
#  279260: 553,
#  200910: 554,
#  386360: 555,
#  311340: 556,
#  286100: 557,
#  245280: 558,
#  15120: 559,
#  404680: 560,
#  364470: 561,
#  22120: 562,
#  239820: 563,
#  314660: 564,
#  529180: 565,
#  343710: 566,
#  371660: 567,
#  252370: 568,
#  346900: 569,
#  295550: 570,
#  282760: 571,
#  239660: 572,
#  13230: 573,
#  24960: 574,
#  232430: 575,
#  367580: 576,
#  252130: 577,
#  313010: 578,
#  375950: 579,
#  102700: 580,
#  220700: 581,
#  65930: 582,
#  22300: 583,
#  359870: 584,
#  380: 585,
#  310380: 586,
#  214490: 587,
#  209540: 588,
#  96100: 589,
#  264240: 590,
#  301640: 591,
#  362490: 592,
#  240720: 593,
#  6920: 594,
#  208140: 595,
#  280: 596,
#  391070: 597,
#  323580: 598,
#  232950: 599,
#  351800: 600,
#  393380: 601,
#  270170: 602,
#  325610: 603,
#  261510: 604,
#  459820: 605,
#  315260: 606,
#  315430: 607,
#  225600: 608,
#  9930: 609,
#  288470: 610,
#  252030: 611,
#  108710: 612,
#  305050: 613,
#  21090: 614,
#  261110: 615,
#  238210: 616,
#  402840: 617,
#  356040: 618,
#  42990: 619,
#  423880: 620,
#  409720: 621,
#  276810: 622,
#  244160: 623,
#  389040: 624,
#  341000: 625,
#  297000: 626,
#  214360: 627,
#  253980: 628,
#  275850: 629,
#  379980: 630,
#  207170: 631,
#  285900: 632,
#  244070: 633,
#  286260: 634,
#  316790: 635,
#  209790: 636,
#  304240: 637,
#  443810: 638,
#  314160: 639,
#  70: 640,
#  9200: 641,
#  255300: 642,
#  288140: 643,
#  233980: 644,
#  250420: 645,
#  431600: 646,
#  476600: 647,
#  291480: 648,
#  19980: 649,
#  213850: 650,
#  303390: 651,
#  352460: 652,
#  282140: 653,
#  213030: 654,
#  206190: 655,
#  263680: 656,
#  1500: 657,
#  202530: 658,
#  350640: 659,
#  604490: 660,
#  337000: 661,
#  335240: 662,
#  18000: 663,
#  228380: 664,
#  304930: 665,
#  280220: 666,
#  420530: 667,
#  242720: 668,
#  22330: 669,
#  332500: 670,
#  252330: 671,
#  265590: 672,
#  91200: 673,
#  346330: 674,
#  552990: 675,
#  287340: 676,
#  264380: 677,
#  48950: 678,
#  250600: 679,
#  427520: 680,
#  265550: 681,
#  460930: 682,
#  361800: 683,
#  221380: 684,
#  250340: 685,
#  409670: 686,
#  369990: 687,
#  388340: 688,
#  495890: 689,
#  9480: 690,
#  225840: 691,
#  374670: 692,
#  344760: 693,
#  414530: 694,
#  286340: 695,
#  238090: 696,
#  360: 697,
#  299540: 698,
#  296870: 699,
#  310360: 700,
#  374570: 701,
#  222640: 702,
#  2100: 703,
#  32400: 704,
#  248820: 705,
#  1520: 706,
#  275200: 707,
#  248170: 708,
#  29180: 709,
#  444640: 710,
#  537180: 711,
#  250760: 712,
#  271820: 713,
#  35450: 714,
#  256290: 715,
#  219990: 716,
#  213670: 717,
#  98400: 718,
#  261180: 719,
#  12500: 720,
#  237850: 721,
#  520720: 722,
#  34010: 723,
#  370510: 724,
#  397340: 725,
#  268500: 726,
#  24840: 727,
#  24240: 728,
#  219910: 729,
#  312750: 730,
#  3483: 731,
#  224760: 732,
#  326150: 733,
#  10500: 734,
#  474750: 735,
#  359310: 736,
#  207140: 737,
#  366220: 738,
#  39150: 739,
#  323060: 740,
#  306020: 741,
#  253920: 742,
#  15620: 743,
#  352400: 744,
#  6020: 745,
#  226720: 746,
#  245620: 747,
#  278970: 748,
#  473690: 749,
#  201480: 750,
#  222980: 751,
#  61600: 752,
#  272270: 753,
#  253250: 754,
#  65800: 755,
#  317360: 756,
#  280160: 757,
#  395520: 758,
#  375600: 759,
#  375510: 760,
#  226860: 761,
#  267490: 762,
#  327510: 763,
#  246620: 764,
#  284390: 765,
#  7670: 766,
#  388090: 767,
#  232790: 768,
#  255220: 769,
#  269770: 770,
#  607200: 771,
#  99300: 772,
#  408120: 773,
#  269030: 774,
#  268650: 775,
#  62000: 776,
#  434420: 777,
#  250620: 778,
#  263980: 779,
#  239070: 780,
#  25900: 781,
#  660880: 782,
#  255370: 783,
#  310370: 784,
#  6040: 785,
#  286570: 786,
#  575640: 787,
#  361990: 788,
#  263280: 789,
#  209520: 790,
#  320820: 791,
#  48800: 792,
#  262120: 793,
#  435030: 794,
#  263360: 795,
#  246110: 796,
#  362620: 797,
#  386070: 798,
#  65790: 799,
#  418370: 800,
#  40300: 801,
#  300: 802,
#  234650: 803,
#  225260: 804,
#  242860: 805,
#  391260: 806,
#  405310: 807,
#  330820: 808,
#  293500: 809,
#  262790: 810,
#  283960: 811,
#  287390: 812,
#  290340: 813,
#  558990: 814,
#  7110: 815,
#  13570: 816,
#  346010: 817,
#  22370: 818,
#  502550: 819,
#  277430: 820,
#  361280: 821,
#  282070: 822,
#  215470: 823,
#  20500: 824,
#  8850: 825,
#  495280: 826,
#  35700: 827,
#  337320: 828,
#  73010: 829,
#  22600: 830,
#  234080: 831,
#  332070: 832,
#  356570: 833,
#  400660: 834,
#  93200: 835,
#  429680: 836,
#  326460: 837,
#  227080: 838,
#  404590: 839,
#  341940: 840,
#  394510: 841,
#  267360: 842,
#  448370: 843,
#  115110: 844,
#  285330: 845,
#  17300: 846,
#  33420: 847,
#  71340: 848,
#  564230: 849,
#  506140: 850,
#  268220: 851,
#  9310: 852,
#  252610: 853,
#  317410: 854,
#  380840: 855,
#  248530: 856,
#  314970: 857,
#  489520: 858,
#  307290: 859,
#  536930: 860,
#  400170: 861,
#  214790: 862,
#  391040: 863,
#  203750: 864,
#  524220: 865,
#  206440: 866,
#  12150: 867,
#  233470: 868,
#  261820: 869,
#  207490: 870,
#  214950: 871,
#  241720: 872,
#  270370: 873,
#  401190: 874,
#  200710: 875,
#  354650: 876,
#  386880: 877,
#  314000: 878,
#  457760: 879,
#  40700: 880,
#  316390: 881,
#  218410: 882,
#  274900: 883,
#  292630: 884,
#  329440: 885,
#  17740: 886,
#  470260: 887,
#  234670: 888,
#  38700: 889,
#  203160: 890,
#  364420: 891,
#  34900: 892,
#  214560: 893,
#  554620: 894,
#  219830: 895,
#  285800: 896,
#  284160: 897,
#  385330: 898,
#  689090: 899,
#  298600: 900,
#  371520: 901,
#  218130: 902,
#  346850: 903,
#  237630: 904,
#  485980: 905,
#  223220: 906,
#  251870: 907,
#  587620: 908,
#  394360: 909,
#  201790: 910,
#  70000: 911,
#  637100: 912,
#  280740: 913,
#  204630: 914,
#  236370: 915,
#  242780: 916,
#  294100: 917,
#  214170: 918,
#  222730: 919,
#  343360: 920,
#  427270: 921,
#  70400: 922,
#  345650: 923,
#  246580: 924,
#  327860: 925,
#  241240: 926,
#  362930: 927,
#  38720: 928,
#  50130: 929,
#  314710: 930,
#  203770: 931,
#  31290: 932,
#  3020: 933,
#  317400: 934,
#  594570: 935,
#  48190: 936,
#  439350: 937,
#  273110: 938,
#  107200: 939,
#  324260: 940,
#  379720: 941,
#  24790: 942,
#  333420: 943,
#  429570: 944,
#  244590: 945,
#  237990: 946,
#  418340: 947,
#  259680: 948,
#  6030: 949,
#  313160: 950,
#  318530: 951,
#  372000: 952,
#  436520: 953,
#  272040: 954,
#  245550: 955,
#  214870: 956,
#  4570: 957,
#  439940: 958,
#  427730: 959,
#  329460: 960,
#  234390: 961,
#  214610: 962,
#  343100: 963,
#  223810: 964,
#  211440: 965,
#  57300: 966,
#  361420: 967,
#  22650: 968,
#  251850: 969,
#  209650: 970,
#  65740: 971,
#  317470: 972,
#  275490: 973,
#  404480: 974,
#  385240: 975,
#  606800: 976,
#  263200: 977,
#  45740: 978,
#  38600: 979,
#  665360: 980,
#  270090: 981,
#  331500: 982,
#  2280: 983,
#  207530: 984,
#  39190: 985,
#  34870: 986,
#  261470: 987,
#  221040: 988,
#  299460: 989,
#  313080: 990,
#  2630: 991,
#  21100: 992,
#  258180: 993,
#  202130: 994,
#  32800: 995,
#  218680: 996,
#  399670: 997,
#  363890: 998,
#  251150: 999,
#  ...}

# %%
with Timer() as test_time:
    test_df = prepare_test_df(test_idx, uids, iids, uid_map, iid_map, weights)
print(f"Took {test_time.interval:.1f} seconds for prepare and predict test data.")  
time_reco1 = test_time.interval
# Out:
# Took 31.2 seconds for prepare and predict test data.

# %%
test_df.sample(5)
# Out:
#            userID  itemID  rating
# 128074       hunk  333930     3.0
# 107668       cuki  271860     3.0
# 77390   all might   41700     3.0
# 76153        nick   45760     6.0
# 133896     cozmin  224600     3.0

# %% [markdown]
# In addition, the predictions of all unseen user-item pairs (e.g. removing those seen in the training data) can be prepared as follows:

# %%
with Timer() as test_time:
    all_predictions = prepare_all_predictions(final_dataframe, uid_map, iid_map, 
                                              interactions=train_interactions,
                                              model=model1, 
                                              num_threads=NO_THREADS)
print(f"Took {test_time.interval:.1f} seconds for prepare and predict all data.")
time_reco2 = test_time.interval
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-118-1b43ea4cea58> in <module>
#       1 with Timer() as test_time:
# ----> 2     all_predictions = prepare_all_predictions(final_dataframe, uid_map, iid_map,
#       3                                               interactions=train_interactions,
#       4                                               model=model1,
#       5                                               num_threads=NO_THREADS)
#
# D:\Anaconda\lib\site-packages\recommenders\models\lightfm\lightfm_utils.py in prepare_all_predictions(data, uid_map, iid_map, interactions, model, num_threads, user_features, item_features)
#     248
#     249     dok_weights = interactions.todok()
# --> 250     all_predictions["rating"] = all_predictions.apply(
#     251         lambda x: dok_weights[x.uid, x.iid], axis=1
#     252     )
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7546             kwds=kwds,
#    7547         )
# -> 7548         return op.get_result()
#    7549
#    7550     def applymap(self, func) -> "DataFrame":
#
# D:\Anaconda\lib\site-packages\pandas\core\apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# D:\Anaconda\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     272
#     273         # wrap results
# --> 274         return self.wrap_results(results, res_index)
#     275
#     276     def apply_series_generator(self) -> Tuple[ResType, "Index"]:
#
# D:\Anaconda\lib\site-packages\pandas\core\apply.py in wrap_results(self, results, res_index)
#     322         constructor_sliced = self.obj._constructor_sliced
#     323         if constructor_sliced is Series:
# --> 324             result = create_series_with_explicit_dtype(
#     325                 results, dtype_if_empty=np.float64
#     326             )
#
# D:\Anaconda\lib\site-packages\pandas\core\construction.py in create_series_with_explicit_dtype(data, index, dtype, name, copy, fastpath, dtype_if_empty)
#     632     if is_empty_data(data) and dtype is None:
#     633         dtype = dtype_if_empty
# --> 634     return Series(
#     635         data=data, index=index, dtype=dtype, name=name, copy=copy, fastpath=fastpath
#     636     )
#
# D:\Anaconda\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     279                 data = data._mgr
#     280             elif is_dict_like(data):
# --> 281                 data, index = self._init_dict(data, index, dtype)
#     282                 dtype = None
#     283                 copy = False
#
# D:\Anaconda\lib\site-packages\pandas\core\series.py in _init_dict(self, data, index, dtype)
#     355         # raises KeyError), so we iterate the entire dict, and align
#     356         if data:
# --> 357             keys, values = zip(*data.items())
#     358             values = list(values)
#     359         elif index is not None:
#
# MemoryError:

# %%
all_predictions.sample(5)
